# %%
import ccxt
import pandas as pd

# %%
print(ccxt.exchanges)
# Out:
# ['alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitforex', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitstamp1', 'bittrex', 'bitvavo', 'bkex', 'bl3p', 'blockchaincom', 'btcalpha', 'btcbox', 'btcex', 'btcmarkets', 'btctradeua', 'btcturk', 'buda', 'bybit', 'cex', 'coinbase', 'coinbaseprime', 'coinbasepro', 'coincheck', 'coinex', 'coinfalcon', 'coinmate', 'coinone', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'flowbtc', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'huobi', 'huobijp', 'huobipro', 'idex', 'independentreserve', 'indodax', 'itbit', 'kraken', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'lbank2', 'luno', 'lykke', 'mercado', 'mexc', 'mexc3', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okex', 'okex5', 'okx', 'paymi
# ...

# %%
getattr(ccxt,'kucoin')()
# Out:
# ccxt.kucoin()

# %%
kucoin = ccxt.kucoin()

# %%
kucoin
# Out:
# ccxt.kucoin()

# %%
pd.DataFrame(kucoin.fetchOHLCV('BTC/USDT', limit=10))
# Out:
#                0        1        2        3        4         5
# 0  1672975440000  16833.9  16835.0  16833.8  16835.0  2.028816
# 1  1672975500000  16835.0  16835.0  16834.9  16834.9  0.780391
# 2  1672975560000  16834.9  16836.7  16834.9  16836.7  0.985537
# 3  1672975620000  16836.7  16836.7  16836.6  16836.7  0.143733
# 4  1672975680000  16836.7  16837.8  16836.6  16837.8  2.001178
# 5  1672975740000  16837.8  16837.8  16837.7  16837.8  0.214138
# 6  1672975800000  16837.7  16837.8  16837.7  16837.8  0.692314
# 7  1672975860000  16837.7  16837.8  16837.7  16837.7  0.615396
# 8  1672975920000  16837.8  16837.8  16837.7  16837.8  0.800230

# %%
def getprices(exchange,symbol):
    inst = getattr(ccxt,exchange)()
    df = pd.DataFrame(inst.fetchOHLCV(symbol,limit=60))
    df.columns = ['Time','Open','High','Low','Close','Volume']
    df.set_index('Time', inplace=True)
    df.index = pd.to_datetime(df.index,unit='ms')
    df = df.astype(float)
    return df

# %%
prices = []
fails = []

for exchange in ccxt.exchanges:
    try:
        prices.append(getprices(exchange,'BTC/USDT'))
        print('prices succesfully pulled for'+exchange)
    except:
        fails.append(exchange)
        print('price pull fail for'+exchange)
# Out:
# prices succesfully pulled foralpaca
# price pull fail forascendex
# prices succesfully pulled forbequant
# prices succesfully pulled forbigone
# price pull fail forbinance
# price pull fail forbinancecoinm
# prices succesfully pulled forbinanceus
# price pull fail forbinanceusdm
# price pull fail forbit2c
# price pull fail forbitbank
# prices succesfully pulled forbitbay
# prices succesfully pulled forbitbns
# prices succesfully pulled forbitcoincom
# prices succesfully pulled forbitfinex
# prices succesfully pulled forbitfinex2
# price pull fail forbitflyer
# prices succesfully pulled forbitforex
# prices succesfully pulled forbitget
# price pull fail forbithumb
# prices succesfully pulled forbitmart
# price pull fail forbitmex
# prices succesfully pulled forbitopro
# price pull fail forbitpanda
# prices succesfully pulled forbitrue
# prices succesfully pulled forbitso
# prices succesfully pulled forbitstamp
# price pull fail forbitstamp1
# prices succesfully pulled forbittrex
# ...

# %%
getprices('bitfinex','BTC/USDT')
# Out:
#                        Open    High     Low   Close    Volume
# Time
# 2019-03-11 10:05:00  3870.1  3870.1  3870.1  3870.1  0.010000
# 2019-03-11 10:06:00  3890.0  3890.0  3890.0  3890.0  0.040000
# 2019-03-11 11:00:00  3875.3  3904.5  3875.3  3904.5  0.009900
# 2019-03-11 11:22:00  3876.9  3876.9  3876.9  3876.9  0.205477
# 2019-03-11 11:24:00  3876.9  3876.9  3876.9  3876.9  1.242443
# 2019-03-11 11:26:00  3876.9  3876.9  3876.9  3876.9  0.076414
# 2019-03-11 11:32:00  3876.9  3907.7  3876.9  3907.7  0.005000
# 2019-03-11 12:04:00  3870.0  3870.0  3870.0  3870.0  0.100000
# 2019-03-11 13:46:00  3866.9  3866.9  3866.9  3866.9  0.300000
# 2019-03-11 13:52:00  3865.5  3865.5  3865.5  3865.5  0.113946
# 2019-03-11 13:53:00  3865.5  3865.5  3865.5  3865.5  0.135050
# 2019-03-11 13:54:00  3865.5  3865.5  3865.5  3865.5  0.000003
# 2019-03-11 14:02:00  3867.9  3868.0  3867.9  3868.0  1.527124
# 2019-03-11 14:08:00  3857.3  3857.3  3857.3  3857.3  1.618800
# ...
